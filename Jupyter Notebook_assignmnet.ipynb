# %% [markdown]
# <h1> My Jupyter Notebook on IBM Watson Studio<h1>

# %% [markdown]
# <b>Maen Al hawari </b>
# <br>
# Academic Consultant

# %% [markdown]
# <i> I’m interested in data science because I have curiosity behind hidden facts in numbers and these facts can be revealed by this new emerged technology  </i>

# %% [markdown]
# <h4>My code multiply 7 with 6 and get the result when it run <h4>

# %%
7*6
# Out:
# 42

# %% [markdown]
#  <hr>
#  My interest in this course as the result of
#  <ul>
# <li>Psssion</li>
# <li>Curiosty</li>
# <li>Seen behind numbers</li>
# </ul>
#  <hr>
# <blockquote>This is Fantastic</blockquote>
